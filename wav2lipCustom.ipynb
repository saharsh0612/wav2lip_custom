# %% [markdown]
# ##Checking session GPU

# %%
# !nvidia-smi
# Out:
# Mon Jun  6 08:41:18 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ##Cloning the SOTA wav2lip github repo

# %%
#title Clone Wav2Lip github repo
# !git clone https://github.com/Rudrabha/Wav2Lip.git
# Out:
# Cloning into 'Wav2Lip'...
# remote: Enumerating objects: 360, done.
# remote: Total 360 (delta 0), reused 0 (delta 0), pack-reused 360
# Receiving objects: 100% (360/360), 522.32 KiB | 2.13 MiB/s, done.
# Resolving deltas: 100% (198/198), done.

# %%
#title Copy wav2lip_gan.pth, wav2lip.pth, face detection models & Requirements.txt
# !cp -ri "/content/drive/MyDrive/Wav2Lip/wav2lip_gan.pth" /content/Wav2Lip/checkpoints/
# !cp -ri "/content/drive/MyDrive/Wav2Lip/wav2lip.pth" /content/Wav2Lip/checkpoints/
# !cd Wav2Lip && pip install -r requirements.txt
# !wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" -O "Wav2Lip/face_detection/detection/sfd/s3fd.pth"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.6 MB 12.4 MB/s
# ...
#      |████████████████████████████████| 20.3 MB 45.6 MB/s
# ...
#      |████████████████████████████████| 67.1 MB 39 kB/s
# ...
#      |████████████████████████████████| 26.6 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 676.9 MB 4.0 kB/s
# ...
#      |████████████████████████████████| 2.6 MB 36.7 MB/s
# ...
#      |████████████████████████████████| 60 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 38.6 MB/s
# ...
#      |████████████████████████████████| 20.2 MB 1.2 MB/s
# ...
#   Created wheel for librosa: filename=librosa-0.7.0-py3-none-any.whl size=1598360 sha256=56dee61eddf5f0bd0a3214f5514339d5c88d57690bca77b52c0a3360295dcec9
#   Stored in directory: /root/.cache/pip/wheels/f5/0d/b1/71a4e1863d7577a218f771df59c7582996580fa07ac79d68fd
# Successfully built librosa
# ...
#   Attempting uninstall: numpy
# ...

# %%
#title Uninstall tensorflow - Confirm with y [ enter ]
# !pip uninstall tensorflow tensorflow-gpu
# Out:
# Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
# Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.8.2+zzzcolab20220527125636.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.8.2+zzzcolab20220527125636
# WARNING: Skipping tensorflow-gpu as it is not installed.

# %%
# Copy wav2lip_gan.pth, wav2lip.pth, face detection models & Requirements.txt
# !cp -ri "/content/drive/MyDrive/Wav2Lip/wav2lip_gan.pth" /content/Wav2Lip/checkpoints/
# !cp -ri "/content/drive/MyDrive/Wav2Lip/wav2lip.pth" /content/Wav2Lip/checkpoints/
# !cd Wav2Lip && pip install -r requirements.txt
# !wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" -O "Wav2Lip/face_detection/detection/sfd/s3fd.pth"
# Out:
# cp: overwrite '/content/Wav2Lip/checkpoints/wav2lip_gan.pth'? y
# cp: overwrite '/content/Wav2Lip/checkpoints/wav2lip.pth'? y
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# --2022-06-02 07:36:03--  https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth
# Resolving www.adrianbulat.com (www.adrianbulat.com)... 45.136.29.207
# Connecting to www.adrianbulat.com (www.adrianbulat.com)|45.136.29.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89843225 (86M) [application/octet-stream]
# Saving to: ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’
#
# Wav2Lip/face_detect 100%[===================>]  85.68M   218MB/s    in 0.4s
#
# 2022-06-02 07:36:03 (218 MB/s) - ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’ saved [89843225/89843225]

# %%
# %cd /content/drive/MyDrive/saharsh
# !unzip /content/drive/MyDrive/saharsh/main.zip
# !unzip /content/drive/MyDrive/saharsh/preprocessed.zip
# Out:
# /content/drive/MyDrive/saharsh
# Archive:  /content/drive/MyDrive/saharsh/main.zip
#   inflating: main/3rd_third/0001.txt
#   inflating: main/11th_eleventh/0002.txt
#   inflating: main/11th_eleventh/0001.txt
#   inflating: main/3rd_third/0001.mp4
#   inflating: main/5th_fifth/0006.txt
#   inflating: main/11th_eleventh/0002.mp4
#   inflating: main/6th_sixth/0002.txt
#   inflating: main/5th_fifth/0002.txt
#   inflating: main/3rd_third/0003.txt
#   inflating: main/3rd_third/0002.txt
#   inflating: main/5th_fifth/0001.txt
#   inflating: main/5th_fifth/0004.txt
#   inflating: main/5th_fifth/0005.txt
#   inflating: main/11th_eleventh/0001.mp4
#   inflating: main/2nd_second/0003.mp4
#   inflating: main/2nd_second/0002.txt
#   inflating: main/3rd_third/0003.mp4
#   inflating: main/3rd_third/0002.mp4
#   inflating: main/5th_fifth/0003.txt
#   inflating: main/5th_fifth/0004.mp4
#   inflating: main/9th_ninth/0002.txt
#   inflating: main/2nd_second/0003.txt
# ...

# %%
# !cp -r /content/drive/MyDrive/saharsh/main /content/Wav2Lip/

# %%
##Adjust the batch size according to your dataset if you face memory error on cuda
# %cd /content/Wav2Lip
# !python preprocess.py --data_root /content/Wav2Lip/main --preprocessed_root /content/Wav2Lip/custom_preprocessed/
# Out:
# /content/Wav2Lip
# Started processing for /content/Wav2Lip/main with 1 GPUs
# 100% 43/43 [30:28<00:00, 42.51s/it]
# Dumping audios...
# 100% 43/43 [00:10<00:00,  4.24it/s]

# %%
# %cd /content/Wav2Lip
# !cp -r /content/drive/MyDrive/saharsh/preprocessed /content/Wav2Lip/
# Out:
# /content/Wav2Lip

# %%
# !cp -r /content/drive/MyDrive/saharsh/train.txt /content/Wav2Lip/filelists/
# !cp -r /content/drive/MyDrive/saharsh/val.txt /content/Wav2Lip/filelists/

# %% [markdown]
# ## Training Expert Lip-Sync

# %%
# !python color_syncnet_train.py --data_root preprocessed/ --checkpoint_dir /content/drive/MyDrive/descCkpt --checkpoint_path /content/drive/MyDrive/descCkpt/checkpoint_step000000001.pth
# Out:
# use_cuda: True
# total trainable params 16435072
# 0it [00:00, ?it/s]Saved checkpoint: /content/drive/MyDrive/descCkpt/checkpoint_step000000001.pth
# Loss: 0.921729326248169: : 1it [00:30, 30.77s/it]
# Loss: 0.9663018584251404: : 1it [00:25, 25.58s/it]
# Loss: 0.7996155023574829: : 1it [00:26, 26.24s/it]
# Loss: 0.8789088726043701: : 1it [00:24, 24.24s/it]
# Loss: 0.7736788988113403: : 1it [00:27, 27.53s/it]
# Loss: 0.9205669164657593: : 1it [00:26, 26.66s/it]
# Loss: 0.7755993604660034: : 1it [00:28, 28.31s/it]
# Loss: 0.872252345085144: : 1it [00:28, 28.32s/it]
# Loss: 0.7657736539840698: : 1it [00:26, 26.10s/it]
# Loss: 0.7938553690910339: : 1it [00:27, 27.00s/it]
# Loss: 0.7418801784515381: : 1it [00:26, 26.04s/it]
# Loss: 0.7526376843452454: : 1it [00:26, 26.24s/it]
# Loss: 0.7115200757980347: : 1it [00:26, 26.84s/it]
# Loss: 0.8034715056419373: : 1it [00:28, 28.02s/it]
# Loss: 0.8722984790802002: : 1it [00:27, 27.38s/it]
# Loss: 0.7558376789093018: : 1it [00:23, 23.87s/it]
# ...

# %%
# %cd /content/Wav2Lip
# Out:
# /content/Wav2Lip

# %%
## it is taking 26.93s/it, which is way too long. Training with this speed may take several weeks.
# !python color_syncnet_train.py --data_root preprocessed/ --checkpoint_dir /content/drive/MyDrive/descCkpt --checkpoint_path /content/drive/MyDrive/descCkpt/checkpoint_step000000001.pth
# Out:
# use_cuda: True
# total trainable params 16435072
# Load checkpoint from: /content/drive/MyDrive/descCkpt/checkpoint_step000000001.pth
# Load optimizer state from /content/drive/MyDrive/descCkpt/checkpoint_step000000001.pth
# Loss: 0.9277713298797607: : 1it [00:23, 23.61s/it]
# Loss: 0.9434923529624939: : 1it [00:25, 25.69s/it]
# Loss: 0.7215943336486816: : 1it [00:25, 25.42s/it]
# Loss: 0.8871098756790161: : 1it [00:22, 22.66s/it]
# Loss: 0.7775766253471375: : 1it [00:24, 24.36s/it]
# Loss: 0.8413553833961487: : 1it [00:27, 27.35s/it]
# Loss: 0.8675032258033752: : 1it [00:25, 25.25s/it]
# Loss: 0.8005450963973999: : 1it [00:25, 25.77s/it]
# Loss: 0.8351567387580872: : 1it [00:28, 28.03s/it]
# Loss: 0.7779065370559692: : 1it [00:26, 26.90s/it]
# Loss: 0.7934157848358154: : 1it [00:25, 25.20s/it]
# Loss: 0.9059377312660217: : 1it [00:25, 25.32s/it]
# Loss: 0.8296986818313599: : 1it [00:25, 25.51s/it]
# Loss: 0.805778980255127: : 1it [00:27, 27.52s/it]
# ...

# %%
## it is taking 26.93s/it, which is way too long. Training with this speed may take several weeks.
# !python color_syncnet_train.py --data_root preprocessed/ --checkpoint_dir /content/drive/MyDrive/descCkpt --checkpoint_path /content/drive/MyDrive/descCkpt/checkpoint_step000000001.pth
# Out:
# use_cuda: True
# total trainable params 16435072
# Load checkpoint from: /content/drive/MyDrive/descCkpt/checkpoint_step000000001.pth
# Load optimizer state from /content/drive/MyDrive/descCkpt/checkpoint_step000000001.pth
# Loss: 0.7865849733352661: : 1it [00:28, 28.14s/it]
# Loss: 0.8378127217292786: : 1it [00:23, 23.10s/it]
# Loss: 0.8165087699890137: : 1it [00:24, 24.57s/it]
# Loss: 0.7665798664093018: : 1it [00:22, 22.79s/it]
# Loss: 0.7093722224235535: : 1it [00:31, 31.74s/it]
# Loss: 0.6705062389373779: : 1it [00:28, 28.32s/it]
# Loss: 0.7725006341934204: : 1it [00:26, 26.86s/it]
# Loss: 0.6583619713783264: : 1it [00:28, 28.50s/it]
# Loss: 0.7890337109565735: : 1it [00:26, 26.54s/it]
# Loss: 0.8574164509773254: : 1it [00:25, 25.71s/it]
# Loss: 0.8507870435714722: : 1it [00:24, 24.54s/it]
# Loss: 0.919173002243042: : 1it [00:23, 23.88s/it]
# Loss: 0.7422159314155579: : 1it [00:30, 30.40s/it]
# Loss: 0.7712141871452332: : 1it [00:23, 23.87s/it]
# ...

# %%
#another trial with preprocess.py file
# %cd /content/Wav2Lip
# !python color_syncnet_train.py --data_root custom_preprocessed/ --checkpoint_dir /content/drive/MyDrive/expDescCkpt
# Out:
# /content/Wav2Lip
# use_cuda: True
# total trainable params 16435072
# 0it [00:00, ?it/s]Saved checkpoint: /content/drive/MyDrive/expDescCkpt/checkpoint_step000000001.pth
# Loss: 0.7430950999259949: : 1it [00:30, 30.87s/it]
# Loss: 0.8992326855659485: : 1it [00:33, 33.21s/it]
# Loss: 0.725837767124176: : 1it [00:29, 29.88s/it]
# Loss: 0.7305445075035095: : 1it [00:31, 31.27s/it]
# Loss: 0.8000661134719849: : 1it [00:33, 33.03s/it]
# Loss: 0.7236955165863037: : 1it [00:34, 34.07s/it]
# Loss: 1.0063786506652832: : 1it [00:29, 29.13s/it]
# Loss: 0.9958849549293518: : 1it [00:33, 33.35s/it]
# Loss: 0.9255003333091736: : 1it [00:35, 35.85s/it]
# Loss: 0.7939119935035706: : 1it [00:28, 28.25s/it]
# Loss: 0.8427026867866516: : 1it [00:28, 28.05s/it]
# Loss: 0.8415015339851379: : 1it [00:34, 34.45s/it]
# Loss: 0.7627440094947815: : 1it [00:28, 28.09s/it]
# Loss: 0.7922831773757935: : 1it [00:34, 34.94s/it]
# Loss: 0.8072671294212341: : 1it [00:33, 33.98s/it]
# ...

# %%
# !cp -r /content/drive/MyDrive/saharsh/preprocessed /content/Wav2Lip/

# %%
# !cp -r /content/drive/MyDrive/descCkpt /content/Wav2Lip

# %% [markdown]
# ##Training custom wav2lip model

# %%
# !python wav2lip_train.py --data_root preprocessed/ --checkpoint_dir /content/drive/MyDrive/wav2lip_ckpt --syncnet_checkpoint_path /content/Wav2Lip/descCkpt/checkpoint_step000000001.pth
# Out:
# use_cuda: True
# total trainable params 36298035
# Load checkpoint from: /content/Wav2Lip/descCkpt/checkpoint_step000000001.pth
# Starting Epoch: 0
# 0it [00:00, ?it/s]Saved checkpoint: /content/drive/MyDrive/wav2lip_ckpt/checkpoint_step000000001.pth
# Evaluating for 700 steps
# L1: 0.24405634924025407, Sync loss: 0.9768742734457388
# L1: 0.16725211838881174, Sync Loss: 0.0: : 3it [17:11, 343.69s/it]
# Starting Epoch: 1
# L1: 0.14956356585025787, Sync Loss: 0.0: : 3it [00:23,  7.79s/it]
# Starting Epoch: 2
# L1: 0.1366262435913086, Sync Loss: 0.0: : 3it [00:24,  8.17s/it]
# Starting Epoch: 3
# L1: 0.1210681473215421, Sync Loss: 0.0: : 3it [00:23,  7.91s/it]
# Starting Epoch: 4
# L1: 0.12194154659907024, Sync Loss: 0.0: : 3it [00:20,  6.93s/it]
# Starting Epoch: 5
# L1: 0.10964350402355194, Sync Loss: 0.0: : 3it [00:19,  6.39s/it]
# Starting Epoch: 6
# L1: 0.09824832528829575, Sync Loss: 0.0: : 3it [00:24,  8.15s/it]
# Starting Epoch: 7
# ...

# %%
# !python inference.py --checkpoint_path /content/drive/MyDrive/wav2lip_ckpt/checkpoint_step000000001.pth --face /content/drive/MyDrive/saharsh/main/11th_eleventh/0001.mp4 --audio /content/drive/MyDrive/custom_preprocessed/10th_tenth/0001/audio.wav
# Out:
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 232
# (80, 989)
# Length of mel chunks: 367
#   0% 0/3 [00:00<?, ?it/s]
#   0% 0/15 [00:00<?, ?it/s]
#   7% 1/15 [00:10<02:26, 10.49s/it]
#  13% 2/15 [00:12<01:44,  8.03s/it]
#  20% 3/15 [00:14<01:14,  6.17s/it]
#  27% 4/15 [00:16<00:53,  4.87s/it]
#  33% 5/15 [00:18<00:39,  3.95s/it]
#  40% 6/15 [00:19<00:29,  3.22s/it]
#  47% 7/15 [00:21<00:21,  2.68s/it]
#  53% 8/15 [00:22<00:16,  2.30s/it]
#  60% 9/15 [00:23<00:12,  2.03s/it]
#  67% 10/15 [00:25<00:09,  1.86s/it]
#  73% 11/15 [00:26<00:06,  1.72s/it]
#  80% 12/15 [00:28<00:04,  1.62s/it]
#  87% 13/15 [00:29<00:03,  1.55s/it]
#  93% 14/15 [00:31<00:01,  1.50s/it]
# 100% 15/15 [00:36<00:00,  2.42s/it]
# Load checkpoint from: /content/drive/MyDrive/wav2lip_ckpt/checkpoint_step000000001.pth
# Model loaded
# 100% 3/3 [00:45<00:00, 15.05s/it]
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
# ...
